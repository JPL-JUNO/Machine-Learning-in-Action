# %% [markdown]
# # 基于最优化方法的最佳回归系数确定

# %% [markdown]
# ## 训练算法：使用梯度上升找到最佳参数

# %%
import logRegres
import importlib

# %%
dataArr, labelMat = logRegres.loadDataSet()

# %%
weights = logRegres.gradAscent(dataArr, labelMat)
weights # array avoid matrix
# Out:
# array([[ 4.12414349],
#        [ 0.48007329],
#        [-0.6168482 ]])

# %% [markdown]
# ## 分析数据：画出决策边界

# %%
import numpy as np

# %%
importlib.reload(logRegres)
# Out:
# <module 'logRegres' from 'd:\\DS_Works\\Machine-Learning-in-Action\\Codes\\logRegres.py'>

# %%
weights = logRegres.gradAscent(dataArr, labelMat)
logRegres.plotBestFit(weight=weights)
