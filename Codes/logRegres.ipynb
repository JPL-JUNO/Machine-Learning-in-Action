# %% [markdown]
# # 基于最优化方法的最佳回归系数确定

# %% [markdown]
# ## 训练算法：使用梯度上升找到最佳参数

# %%
import logRegres
import importlib

# %%
dataArr, labelMat = logRegres.loadDataSet()

# %%
weights = logRegres.gradAscent(dataArr, labelMat)
weights # array avoid matrix
# Out:
# array([[ 4.12414349],
#        [ 0.48007329],
#        [-0.6168482 ]])

# %% [markdown]
# ## 分析数据：画出决策边界

# %%
import numpy as np

# %%
importlib.reload(logRegres)
# Out:
# <module 'logRegres' from 'c:\\Notes\\Machine-Learning-in-Action\\Codes\\logRegres.py'>

# %%
weights = logRegres.gradAscent(dataArr, labelMat)
logRegres.plotBestFit(weight=weights)

# %% [markdown]
# ## 训练算法：随机梯度上升

# %%
importlib.reload(logRegres)
# Out:
# <module 'logRegres' from 'c:\\Notes\\Machine-Learning-in-Action\\Codes\\logRegres.py'>

# %%
weights = logRegres.stocGradAscent0(np.array(dataArr), labelMat)

# %%
logRegres.plotBestFit(weight=weights)

# %%
importlib.reload(logRegres)
# Out:
# <module 'logRegres' from 'c:\\Notes\\Machine-Learning-in-Action\\Codes\\logRegres.py'>

# %%
dataArr, labelMat = logRegres.loadDataSet()
weights = logRegres.stocGradAscent1(np.array(dataArr), labelMat)

# %%
logRegres.plotBestFit(weights)

# %% [markdown]
# # 示例：从疝气病症预测病马的死亡率

# %% [markdown]
# ## 准备数据：处理数据中的缺失值

# %% [markdown]
# ## 测试算法：用 Logistic 回归进行分类

# %%
importlib.reload(logRegres)
# Out:
# <module 'logRegres' from 'c:\\Notes\\Machine-Learning-in-Action\\Codes\\logRegres.py'>

# %%
logRegres.multiTest()
# Out:
# The error rate of this test is : 0.31343283582089554
# The error rate of this test is : 0.417910447761194
# The error rate of this test is : 0.2835820895522388
# The error rate of this test is : 0.43283582089552236
# The error rate of this test is : 0.373134328358209
# The error rate of this test is : 0.29850746268656714
# The error rate of this test is : 0.29850746268656714
# The error rate of this test is : 0.40298507462686567
# The error rate of this test is : 0.2835820895522388
# The error rate of this test is : 0.34328358208955223
# After 10 iterations the average error rate is : 0.3447761194029851
